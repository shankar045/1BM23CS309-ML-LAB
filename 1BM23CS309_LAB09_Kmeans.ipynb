# %% [markdown]
# <a href="https://colab.research.google.com/github/shankar045/1BM23CS309-ML-LAB/blob/main/1BM23CS309_LAB09_Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

df = pd.read_csv("/content/iris (1) (1).csv")

X = df[['petal_length', 'petal_width']]

scaler = StandardScaler()
X = scaler.fit_transform(X)

wcss = []
for k in range(1, 11):
    km = KMeans(n_clusters=k, n_init=10)
    km.fit(X)
    wcss.append(km.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel('K')
plt.ylabel('WCSS')
plt.show()

kmeans = KMeans(n_clusters=3, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  cluster
# 0           5.1          3.5           1.4          0.2  Iris-setosa        0
# 1           4.9          3.0           1.4          0.2  Iris-setosa        0
# 2           4.7          3.2           1.3          0.2  Iris-setosa        0
# 3           4.6          3.1           1.5          0.2  Iris-setosa        0
# 4           5.0          3.6           1.4          0.2  Iris-setosa        0
